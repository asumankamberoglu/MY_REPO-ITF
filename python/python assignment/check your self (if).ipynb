# %%
a = 3
while a**2 < 299:
    print('I will stop smoking')
    a += 3

# %%
total = 149
country = "FR"

if country == "FR":
    if total <= 50:
        print("Shipping Cost is  €30")
    elif total <= 100:
        print("Shipping Cost is €15")
    elif total <= 150:
        print("Shipping Costs €10")
    else:
        print("Free Shipping")
if country == "DE": 
    if total <= 50:
        print("Shipping Cost is  €25")
    else:
        print("Free Shipping")

# %% [markdown]
# Tom, a 13-year-old boy, wants to play with PlayStation-4. Since he couldn't afford it, he started to save money to reach the price of PS4 (variable ps4_price). Let's write a program to tell him how much time left before he can play with PS4. So write a simple code that gets the amount of money Tom saved and prints one of the three options below according to saved_amount :
#
# If saved_amount is less than or equal to ps4_price/2 then print : "You must save more, keep saving!"
# If saved_amount is greater than ps4_price/2 then print : "You saved more than half, keep saving!"
# If saved_amount is greater than ps4_price then print : "Yippee! You can buy your PS4"
# Note: Variable ps4_price is created for you. You can use it in your code without defining it.

# %%
saved_amount = int(input('Please enter your saved amount: '))
if saved_amount <= ps4_price/2:
    print('You must save more, keep saving!')
elif saved_amount > ps4_price/2 and saved_amount < ps4_price:
    print('You saved more than half, keep saving!')
else:
    print('Yippee! You can buy your PS4')

# %% [markdown]
# Mrs Brown is a Math teacher. She wants to write a program that gets the numeric grades of her students, assigns them to variable math_mark and prints them as letter-based grades defined below:
#
# 85-100 ➔ A (Excellent)
# 70-84 ➔ B (Good)
# 60-69 ➔ C (Medium)
# 45-59 ➔ D (Not Bad)
# 0-44 ➔ F (Failed)
#
# Write your program using if, elif and else statements.

# %%
math_mark = int(input('Please enter the mark: '))

if math_mark >= 85:
    print('A (Excellent)')
elif math_mark < 85 and math_mark >= 70:
    print('B (Good)')
elif math_mark < 70 and math_mark >= 60:
    print('C (Medium)')
elif math_mark < 60 and math_mark >= 45:
    print('D (Not Bad)')
else:
    print('F (Failed)')

# %%
a = 998
if a >= 999 :
    print(a ** 0)  

else :
    print(a * 2)

# %%
a and b are two different numbers. Write down the correct order of the following codes to print the bigger number than the other. (e.g. 1-2-3-4)

1) if b > max:
2) max = b
3) print(max)
4) max = a

4 - 1 - 2 -3

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
for day in range(len(weekdays)):
    print('Day', day+1, ':', weekdays[day])
    
    
# Fill in the missing words that output of the code above will be:

# Day 1 : Monday
# Day 2 : Tuesday
# Day 3 : Wednesday
# Day 4 : Thursday
# Day 5 : Friday

# %%
a = 49
while ...............:
    print(a)
    a += 5
    
  1) a <= 62
2) a % 2 != 0
3) a > 10  
3-1-2

# %%
month = "......"
spring = "September, April, January"
autumn = "March, October, July"

if (month in spring) or (month in autumn):
    if month in autumn:
        print("This is a spring month")
    else:
        print("This is an autumn month")
else:
    print("This month is not categorized")
    
# # The correct answer is: August → This month is not categorized, 
# July → This is a spring month, 
# April → This is an autumn month

# %%
number = int(input('Please enter a number: '))
count = 0
while count < number:
    print(count**2)
    count += 1

# %% [markdown]
# Write a program that prints each item and its corresponding type from the following list.
#
# sample_list = [{"section":5, "topic":2}, 'clarusway', [1, 4], 2020, 3.14, 1+618j, False, (10, 20)]
#
# One of the output line as an example: The type of clarusway is <class 'str'>.
#
# Note: Write the program with for statement.

# %%
sample_list = [{"section":5, "topic":2}, 'clarusway', [1, 4], 2020, 3.14, 1+618j, False, (10, 20)]
for i in sample_list:
    print('The type of', i, 'is', type(i))

# %% [markdown]
# Fill in the blanks to complete the program that prints all elements of the flowers list below each on separate lines such as :
#
# Rose
# Orchid
# Tulip

# %%
flowers = ['Rose', 'Orchid', 'Tulip']
count1 = len(flowers)
count2 = 0

while count1 > 0 :
    print(flowers[count2])
    count1 -=1
    count2 +=1

# %%
n = int(input('enter a number between 1-10'))

for i in range(5):
    print('{}x{} = '.format(n, i), n*i)

# %%
times = int(input("How many times should I say 'I love you'"))

for i in range(times):
    print('I love you')

# %%
text = ['one','two','three','four','five']
numbers = [1, 2, 3, 4, 5]
for x, y in zip(text, numbers):
    print(x, ':', y)

# %%
who = ['I am ', 'You are ']
mood = ['happy', 'confident']
for i in who:
    for ii in mood:
        print(i + ii)

# %%
empty = []

# %%
max(empty, default = 'boş')
# Out:
# 'boş'

# %%
max(empty, default = True)
# Out:
# True

# %%
max(empty, default = 22)
# Out:
# 22

# %%
number = [1, 3, 5, 8, 8, 9, 5, 5, 7, 7, 7, 7]

# %%
number.count(7)
# Out:
# 4

# %%
max(number)
# Out:
# 9

# %%
number.count(max(number))
# Out:
# 1

# %%
max(number, key = number.count) # önce en çok tekrar edeni bul, bunlarında en büyüğünü seç
#count burada tüm elemanları teker teker alır kaç kez tekrar ettiğine bakar, sonra max number yani en çok tekrar eden
# en yüksek rakamı alır.
# Out:
# 7

# %%
max("player 1:","player 2:", key = input)
# Out:
# player 1:5
# player 2:7
# 'player 2:'

# %%
numbers = [1, 3, 7, 4, 3, 0, 3, 6, 3] # kaç kez tekrar ettiği
a = max(numbers, key = numbers.count)
print(a)
# Out:
# 3

# %%
numbers.count(max(numbers, key = numbers.count)) # tekrar sıklığı
# Out:
# 4
