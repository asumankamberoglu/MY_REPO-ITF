# %%
for i in range (2, 5):
  for j in [*range(1, i)][::-2]:
    if j == i - 1:
      print("Merhaba")

  else:
    print('Olmadı')
else:
  print("üzgünüm")
# Out:
# Merhaba
# Olmadı
# Merhaba
# Olmadı
# Merhaba
# Olmadı
# üzgünüm

# %%
[*range(1, 3)]
# Out:
# [1, 2]

# %%
[1, 2][::-1]
# Out:
# [2, 1]

# %%
[1, 2][::-2]
# Out:
# [2]

# %%
[1, 2, 3, 4][::-2]
# Out:
# [4, 2]

# %%
a = "portakal"
a[::-1]
a[::-2]
# Out:
# 'lkto'

# %%
a=range(1001)
b=a[::3]
c=a[::5]
x=set(b).intersection(set(c))
print(sum(x))
# Out:
# 33165

# %%
a=range(1001)
b=a[::15]
x=set(b).intersection(set(a))
print(sum(x))
# Out:
# 33165

# %%
x=set(range(1001)).intersection(set(a[::15]))
print(sum(x))
# Out:
# 33165

# %%
print(sum(set(range(1001)).intersection(set(a[::15]))))
# Out:
# 33165
