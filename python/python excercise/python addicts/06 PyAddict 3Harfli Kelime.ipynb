# %%
27 Mayıs 2022

# %%
Edwin - Instructor
Girilen 3 harfli bir kelimenin harflerinin içinde ünlü harf olup olmadığını
ve eğer ünlü harf var ise bunun kaçıncı harf olduğunu 
if-elif-else statement ile yazdırabilir misiniz

# %%
# çözümüm

kelime = list(input("Lütfen 3 harfli bir kelime giriniz : "))
ünlüler = ["e", "ı", "o", "ü", "a", "i", "ö", "u"]
if kelime[0] in ünlüler:
     print(kelime[0], 'harfi', kelime.index(kelime[0]), 'numaralı indexte')
elif kelime[1] in ünlüler:
    print(kelime[1], 'harfi', kelime.index(kelime[1]), 'numaralı indexte')
elif kelime[2] in ünlüler:
     print(kelime[2], 'harfi', kelime.index(kelime[2]), 'numaralı indexte')
else:
    print("Kelime içinde ünlü harf yok")
# Out:
# Lütfen 3 harfli bir kelime giriniz : pol
# o harfi 1 numaralı indexte

# %%
# gregor

kelime = input("üç harfli bir kelime giriniz: ")

ünlü_harfler = set("aeıioöuü")

if ünlü_harfler.intersection(kelime) :
    print("ünlü harf mevcut")
     
    if kelime[0] and kelime[1] and kelime[2] in set(ünlü_harfler):
        print("tüm harfler ünlüdür")  
        
    elif (kelime[1] and kelime[2]) in set(ünlü_harfler):
        print("iki ve üçüncü harf ünlüdür")    
        
    elif (kelime[0] and kelime[2]) in set(ünlü_harfler):
        print("bir ve üçüncü harf ünlüdür") 
        
    elif (kelime[0] and kelime[1]) in set(ünlü_harfler):
        print("ilk iki harf ünlüdür")  
        
    elif kelime[0] in set(ünlü_harfler) :
        print("ilk harf ünlüdür")
    
    elif kelime[1] in set(ünlü_harfler) :
        print("ilk harf ünlüdür")
    
    elif kelime[2] in set(ünlü_harfler) :
        print("ilk harf ünlüdür")   
else :
    print("ünlü harf yoktur")
# Out:
# üç harfli bir kelime giriniz: fbe
# ünlü harf mevcut
# tüm harfler ünlüdür

# %%
#F3733 - Rabia ---> enumerate * * *

word=input("Please enter a word in english : ")
vowels={'a', 'e', 'i', 'o', 'u'}
if len(set(word).intersection(vowels))==0:
  print("There were no vowels in your word")
else:
  for i, n in enumerate(word, 1):
    if n in vowels:
      print("The {}th element of your word is a vowel".format(i))
# Out:
# Please enter a word in english : pol
# The 2th element of your word is a vowel

# %%
# F3795 Nedim 
keli = input("Kelime giriniz(3 harfli): ")
keliy = set(keli)
ses = "euoüaiöı"
ses1 = set(ses)
#Start it
ab = keliy.intersection(ses1)

if len(keli) == 3:
    if bool(ab) == True:
        for i in keli:
            if bool(set(i).intersection(ab)):
                print(f"{i} Harfler arasında",str(keli.index(i)+1)+". sırada.")
                
    else:
        print("That doesnt even include any vowel!")
else:
    print("3 harfli değil.")
# Out:
# Kelime giriniz(3 harfli): pop
# o Harfler arasında 2. sırada.

# %%
# F3625-Buddy 

a = input ('enter a three letter word :').lower()
b = {"a", "e", "ı", "i", "o", "ö", "u", "ü"}
intersec = set(a) & b
if len(a)!=3:
  print("Your input must be 3 letter, try again.")
if len(a) == 3 and len(intersec) == 0:
  print("There is no vowel letter in your input.")
if len(a) == 3 and len(intersec) > 0:
  print(f"The letters {intersec} from the words you entered is/are vowels")
  if a[0] in b :
    print("First letter is wowel")
  if a[1] in b :
    print('Second letter is wowel')
  if a[2] in b :
    print('Third letter is wowel')
# Out:
# enter a three letter word :opo
# The letters {'o'} from the words you entered is/are vowels
# First letter is wowel
# Third letter is wowel

# %%
sözcük = list((input("3 harfli bir sözcük giriniz : ")).lower())
ünlü = ["a","e","i", "ı","o","u", "ö", "ü"]
if len(sözcük) == 3 : 
    if (sözcük[0] in ünlü) and (sözcük[1] in ünlü) and (sözcük[2] in ünlü) :
        print("üç harf te ünlüdür") 
    elif (sözcük[0] in ünlü) and (sözcük[1] in ünlü) :
        print("ilk iki harf ünlüdür")
    elif (sözcük[1] in ünlü) and (sözcük[2] in ünlü) :  
        print("ikinci ve üçüncü harf ünlüdür")     
    elif (sözcük[0] in ünlü) and (sözcük[2] in ünlü) :
        print("ilk ve üçüncü harf ünlüdür")    
    elif sözcük[0] in ünlü :
        print("ilk harf ünlüdür")
    elif sözcük[1] in ünlü :
        print("ikinci harf ünlüdür")
    elif sözcük[2] in ünlü :
        print("üçüncü harf ünlüdür")
    else :
        print("ünlü harf yoktur") 
else :
    print("girilen sözcük 3 harfli değildir lütfen tekrar deneyiniz")
# Out:
# 3 harfli bir sözcük giriniz : eae
# üç harf te ünlüdür

# %%
# F1324-Asuman

check = ["a", "e", "o", "ö", "u", "ü", "ı", "i"]
word = (input("word?:"))
wordünlü= set(word)
while len(word) < 4:
    if wordünlü.intersection(check):
        print('kelime ünlü harf içermektedir')
        for i in wordünlü.intersection(check):
          print("{} harfi {} kelimesinde {} kez geçiyor".format(i, word, word.count(i)))
          print(f" kelimedeki - {i} - ünlü harfinin indeks numarası: ", word.find(i))
        break
    else:
        print('kelime ünlü harf içermemektedir')
        break
if len(word) > 3:
  print('kelime sayısı 3 den fazladır')
# Out:
# word?:wa
# kelime ünlü harf içermektedir
# a harfi wa kelimesinde 1 kez geçiyor
#  kelimedeki - a - ünlü harfinin indeks numarası:  1

# %%
# F3791 - Noah

vowels = {"a","e","i","o","u"}
word = input("Type a word: ").lower()
word_set = set(word)

commons = word_set.intersection(vowels)
commons = list(commons)

if len(commons) > 0:
  for i in word:
    if i in commons:
      print(f"{i.upper()} letter is your {word.index(i) +1}th letter")
else:
  print("There is not matching vowel")

# %%
# F3808-Haliboss  
sesli = list("aAeEIıİiUuÜüOoÖö")
x = list(input("lütfen üç harfli bir kelime giriniz: "))
  
if x[0] or x[2] or x[3] in sesli :
  print("sesli harf içeriyor")
else:
  print("sesli harf içermemektedir")
   
if x[0] in sesli:
  print("birinci harf, sesli harftir")
  if x[1] in sesli: 
    print("ikinci harf, sesli harftir")
    if x[2] in sesli:
      print("üçüncü harf, sesli harftir")  
  elif x[1] in sesli: 
    print("ikinci harf, sesli harftir")
  elif x[2] in sesli:
    print("üçüncü harf, sesli harftir") 
  else:   
    print("Hatalı giriş yaptınız")
elif x[1] in sesli: 
  print("ikinci harf, sesli harftir")
  if x[2] in sesli:
    print("üçüncü harf, sesli harftir")
  else: 
    print()
elif x[2] in sesli:
  print("üçüncü harf, sesli harftir")
elif len(x) > 3 :
  print("üç haneden fazla giriş yaptınız") 
else: 
  print("Hatalı giriş yaptınız")
# Out:
# lütfen üç harfli bir kelime giriniz: opl
# sesli harf içeriyor
# birinci harf, sesli harftir
# Hatalı giriş yaptınız

# %%
# F3615-Burak  
ünlü = ["a", "e", "o", "ö", "u", "ü", "ı", "i"]
kelime = str(input("Üç harfli bir kelime giriniz: "))
# girilen kelimede sadece 1 ünlü harf var ise bu şekilde,
# 1 den fazla ise aşağıdaki koda birkaç elif daha eklemek gerekir.
if kelime[0] in ünlü:
    print(f"1'inci harf {kelime[0]} ünlü harftir")
elif kelime[1] in ünlü:
    print(f"2'nci harf {kelime[1]} ünlü harftir")
elif kelime[2] in ünlü:
    print(f"3'üncü harf {kelime[2]} ünlü harftir")
else:
    print("Girilen kelimede ünlü harf yok")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21604/1053992664.py in <module>
#       1 # F3615-Burak
#       2 ünlü = ["a", "e", "o", "ö", "u", "ü", "ı", "i"]
# ----> 3 kelime = str(input("Üç harfli bir kelime giriniz: "))
#       4 # girilen kelimede sadece 1 ünlü harf var ise bu şekilde,
#       5 # 1 den fazla ise aşağıdaki koda birkaç elif daha eklemek gerekir.
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
# F3707 Hugo

check = input("Please enter a 3 letter word")
check_set = set(check)
wovels = set("aeiouAEIOU")
output = list(check_set & wovels)
if len(output) == 0:
    print("There is no wovel in this letter")
else:
    for i in output:
        print(f"The wovel is - {i} - and the index no is: ", check.find(i))
# Out:
# Please enter a 3 letter wordeai
# The wovel is - i - and the index no is:  2
# The wovel is - e - and the index no is:  0
# The wovel is - a - and the index no is:  1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# F3561 - Hüseyin 

while True:
    check=input("Type a 3 char word:")
    check_set=set(check)
    vowel=set("aioueAIOUE")
    if len(check)>3:
        print("Your input is more than 3 char, try again.")
        continue
    if check_set&vowel==set():
        print("There is no vowel char in your input.")
        break
    i=0
    while i<=2:
        if check[i] in vowel:
            print(f"There is a vowel char in your input and its index no:{i}")
            i+=1
            continue
        else:
            i+=1
            continue
    break

# %% [markdown]
# ![image.png](attachment:image.png)
