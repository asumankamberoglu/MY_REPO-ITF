# %% [markdown]
# ![image.png](attachment:image.png)

# %%
word = input()

for i in word:
    print(i, end = "-")
print('\b')
# Out:
# clarusway
# c-l-a-r-u-s-w-a-y

# %%
word = input("Give me a word :")
counter =0

for i in word:
    counter += 1
     
    if counter < len(word):
        print(i, end = "-")
# Out:
# Give me a word :sksosks
# s-k-s-o-s-k-

# %%
kelime = "Clarusway"
tire = "-".join(kelime)
print(tire)
# Out:
# C-l-a-r-u-s-w-a-y
