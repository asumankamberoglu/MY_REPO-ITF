# %% [markdown]
# **Exercise - 176 | ?def | ?for loop | ?index() | ?replace() | ?strip() | ?find()**
#
# Complete the solution so that it strips all text that follows any of a set of comment markers passed in. Any whitespace at the end of the line should also be stripped out.
#
# Example:
#
# Given an input string of:
#
# ![image.png](data:image/png;base64,...)
#
# The output expected would be:
#
# ![image.png](data:image/png;base64,...)
#
# The code would be called like so:
#
# ![image.png](data:image/png;base64,...)

# %%
def solution(string,markers):
  for i in string:
    if i in markers:
      new_string=string[string.index(i):string.index(i)+string[string.index(i):].find("\n")]
      string=string.replace(new_string,"")
  for i in string[::-1]:
    if i in markers:
      string=string.replace(string[string.index(i):],"")
      break
  return print(string.strip())
solution("apples, pears # and bananas\ngrapes\nbananas !apples", ["#", "!"])
# Out:
# apples, pears
# grapes
# bananas
