# %% [markdown]
# **Exercise - 057 | ?input() | ?len() | ?split() | ?strip()**
#
# ![image.png](data:image/png;base64,...)

# %%
s = input("Lütfen bir cümle yazınız: ").split()
print(len(s[-1]))
print(s)
# Out:
# Lütfen bir cümle yazınız: Republic of Turkey
# 6
# ['Republic', 'of', 'Turkey']

# %%
s = input("Lütfen bir cümle yazınız: ").strip().split()
print(len(s[-1]))
print(s)
# Out:
# Lütfen bir cümle yazınız: Republic of Turkey
# 6
# ['Republic', 'of', 'Turkey']
