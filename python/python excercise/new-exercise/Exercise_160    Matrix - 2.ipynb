# %% [markdown]
# **Exercise - 160 | ?def | ?len() | ?append() | ?pop() | ?list() | ?zip() | ?extend()**
#
# ![image.png](data:image/png;base64,...)

# %%
def snail(array) :
  liste = []
  liste2 = []
  while len(array) :
    liste.append(array.pop(0))
    array = list(zip(*array))[::-1]
  return liste

array = [[1, 2, 3, 1],
         [4, 5, 6, 4],
         [7, 8, 9, 7],
         [7, 8, 9, 7]]
snail(array)
# Out:
# [[1, 2, 3, 1], (4, 7, 7), (9, 8, 7), (7, 4), (5, 6), (9,), (8,)]

# %%
def snail(array):
  new_array=[]
  while True:
    if array:
      new_array.extend(array.pop(0))
      array=list(zip(*array))[::-1]
    else:
      break
  return new_array

array = [[1, 2, 3, 4],
         [6, 5, 4, 5],
         [7, 2, 3, 6],
         [8, 9, 8, 7]]
snail(array)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 8, 7, 6, 5, 4, 3, 2]
