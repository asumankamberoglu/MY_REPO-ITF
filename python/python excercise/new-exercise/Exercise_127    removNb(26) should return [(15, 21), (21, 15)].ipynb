# %% [markdown]
# **Exercise - 127 | ?def | ?range() | ?sum() | ?comprehension | ?nested for loop | ?append()**
#
# - A friend of mine takes the sequence of all numbers from 1 to n (where n > 0).
# - Within that sequence, he chooses two numbers, a and b.
# - He says that the product of a and b should be equal to the sum of all numbers in the sequence, excluding a and b.
# - Given a number n, could you tell me the numbers he excluded from the sequence?
#
# The function takes the parameter: **n** (n is always strictly greater than 0) and returns an array or a string (depending on the language) of the form:
#
# ![image.png](data:image/png;base64,...)

# %%
def removeNb(num) :
  return [[i,j] for i in range(1,num+1) for j in range(1,num+1) if i * j  == sum([i for i in range(1,num + 1)]) - i - j]

# %%
n = int(input("Please enter a number: "))
liste = []
for i in range(1, n+1) :
  for j in range(1, n+1) :
    if i * j == ((n * (n+1)) / 2 - (i+j)):
      liste += [[i, j]]
print(liste)
# Out:
# Please enter a number: 26
# [[15, 21], [21, 15]]

# %%
n = int(input("Please enter a number: "))
liste = []
for i in range(1, n+1) :
  for j in range(1, n+1) :
    if i * j == ((n * (n+1)) / 2 - (i+j)):
      liste.append([i, j])
print(liste)
# Out:
# Please enter a number: 26
# [[15, 21], [21, 15]]

# %%
n = int(input("Please enter a number: "))
def removeNb(number) :
  return [[i,j] for i in range(1,number+1) for j in range(1,number+1) if i * j  == sum([x for x in range(1,number+1)]) - (i+j)]
removeNb(n)
# Out:
# Please enter a number: 26
# [[15, 21], [21, 15]]
