# %% [markdown]
# **Exercise - 144 | ?def | ?while loop | ?indexing | ?range() | ?len() | ?input() | ?join() | ?abs() | ?index() | ?for loop**
#
# **Alphabet Rangoli**
#
# You are given an integer, . Your task is to print an alphabet rangoli of size . (Rangoli is a form of Indian folk art based on creation of patterns.)
# Different sizes of alphabet rangoli are shown below:
#
# ![image.png](data:image/png;base64,...)
#
# The center of the rangoli has the first alphabet letter a, and the boundary has the  alphabet letter (in alphabetical order).
#
# **Function Description**
#
# Complete the rangoli function in the editor below.
#
# rangoli has the following parameters:
#
# - int size: the size of the rangoli
#
# **Returns**
#
# - string: a single string made up of each of the lines of the rangoli separated by a newline character (\n)
#
# **Input Format**
#
# Only one line of input containing , the size of the rangoli.
#
# **Sample Input**
#
# 5
#
# **Sample Output**
#
# ![image.png](data:image/png;base64,...)

# %%
def rangoli(x):
    alphabe = "abcdefghijklmnopqrstuvwxyz"
    text = ""
    while "a" not in text:
        text = alphabe[x - 1]
        print("-" * ((x - 1) * 2) + text + "-" * ((x - 1) * 2))
        count = 0
        for i in range(1, x):
            text =  "".join(text[:i + count]) + "-" + alphabe[x - 1 - i]
            text += text[-2::-1]
            print("-" * ((x - 1 - i) * 2) + text + "-" * (((x - 1) - i) * 2))
            count += 1
    while len(text) > 1:
        count = text.index('a')
        for i in range(count, 1, -2):
            text = text[:i - 1]
            text += text[-2::-1]
            print("-" * ((x*2) - i) + text + "-" * ((x*2) - i))
rangoli(int(input("Please enter a size of alphabet rangoli: ")))
# Out:
# Please enter a size of alphabet rangoli: 5
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------

# %%
num = int(input(""))
alpha = "abcdefghijklmnopqrstuvwxyz"[0:num]
for i in range(num-1, -num, -1):
  x = abs(i)
  satır = alpha[num: x:-1] + alpha[x:num]
  print(x * "--", "-".join(satır), x * "--")
# Out:
# 5
# -------- e --------
# ------ e-d-e ------
# ---- e-d-c-d-e ----
# -- e-d-c-b-c-d-e --
#  e-d-c-b-a-b-c-d-e
# -- e-d-c-b-c-d-e --
# ---- e-d-c-d-e ----
# ------ e-d-e ------
# -------- e --------
