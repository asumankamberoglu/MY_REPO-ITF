# %% [markdown]
# **Exercise - 164 | ?def | ?dictionary | ?for loop | ?count() | ?max() | ?get()**
#
# Create a function that takes a list of football clubs with properties: **name, wins, loss, draws, scored, conceded,** and returns the **team name** with the highest number of points. If two teams have the **same number of points**, return the team with the **largest goal difference**.
#
# How to Calculate Points and Goal Difference
#
# ![image.png](data:image/png;base64,...)

# %%
def function_of_team(dict1):
    dict1 = {}
    name = input("Please enter your team : ")
    wins = int(input("Please enter the wins rate : "))
    loss = int(input("Please enter losses rate of team : "))
    draws = int(input("Please enter the draws of team : "))
    scored = int(input("Please enter the scores of the team : "))
    conceded = int(input("Please enter the concede of the team : "))
    dict1["name"] = name
    dict1["wins"] = wins
    dict1["draws"] = draws
    dict1["scored"] = scored
    dict1["loss"] = loss
    dict1["conceded"] = conceded
    return dict1
a = function_of_team(dict1={})
b = function_of_team(dict1={})
c = function_of_team(dict1={})
dict2 = {}
champions = [a, b, c]
for i in champions:
    count  = 0
    count = count + i["wins"]*3 + i["loss"]*0 + i["draws"] * 1
    dict2[i["name"]] = count
a = (max(dict2, key=dict2.get))
print(a)
# Out:
# Please enter your team : Manchester United
# Please enter the wins rate : 79
# Please enter losses rate of team : 11
# Please enter the draws of team : 10
# Please enter the scores of the team : 145
# Please enter the concede of the team : 21
# Please enter your team : Arsenal
# Please enter the wins rate : 65
# Please enter losses rate of team : 22
# Please enter the draws of team : 13
# Please enter the scores of the team : 102
# Please enter the concede of the team : 34
# Please enter your team : Chelsea
# Please enter the wins rate : 78
# Please enter losses rate of team : 11
# Please enter the draws of team : 11
# Please enter the scores of the team : 140
# Please enter the concede of the team : 27
# Manchester United
