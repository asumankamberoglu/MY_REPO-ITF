# %% [markdown]
# **Exercise - 45 |?in |?set() | ?input()**
#
# ![image (2).png](data:image/png;base64,...)

# %%
w1, w2 = input("Enter first word: "), input("Enter second word: ")
print(w1 in w2)
# Out:
# Enter first word: Yn
# Enter second word: PYnative
# True

# %%
# Alternative

s1 = input("ilk kelime: ")
s2 = input("ikinci kelime: ")

if set(s1)-set(s2) == set():
    print("balanced")
else:
    print("not balanced")
# Out:
# ilk kelime: Ynf
# ikinci kelime: PYnative
# not balanced

# %%
set("abcd") - set("ab") == set()
# Out:
# False

# %%
set("ab") - set("abcd") == set()
# Out:
# True
